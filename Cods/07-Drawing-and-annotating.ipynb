# %% [markdown]
# #### cv2.line(image, starting cordinates, ending cordinates, color, thickness)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = np.zeros((512,512,3), np.uint8)
cv2.line(image, (40,50), (120,400), (200,300,50),7)
cv2.imshow("Blue Line", image)
plt.imshow(image[...,::-1])
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# #### cv2.rectangle(image, starting vertex, opposite vertex, color, thickness)

# %%
image = np.zeros((512,512,3), np.uint8)
cv2.rectangle(image,(100,50),(250,200),(0,200,250),8)
cv2.imshow("Rectangle", image)
plt.imshow(image[...,::-1])
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("./images/girl.jpg")
cv2.rectangle(img, (250,100), (650,650), (200,200,0),7)
plt.imshow(img[...,::-1])

# %% [markdown]
# #### cv2.cirlce(image, center, radius, color, thickness)

# %%
image = np.zeros((512,512,3), np.uint8)
cv2.circle(image, (200,200), 100, (200,0,150),7)
cv2.imshow("Circle", image)
plt.imshow(image[...,::-1])
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
ellipse = np.zeros((512,512,3), np.uint8)

cv2.ellipse(ellipse, (200, 200), (150, 100), 45, 90, 360, (0,255,255), -1)

cv2.imshow("Ellipse", ellipse)
plt.imshow(ellipse[...,::-1])
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image = np.zeros((512,512,3), np.uint8)

pts = np.array( [[20,60], [200,40], [400,200], [100,300]], np.int32)
# Let's now reshape our points in form  required by polylines
pts = pts.reshape((-1,1,2))

cv2.polylines(image, [pts], True, (200,0,255), 3)
cv2.imshow("Polygon", image)
plt.imshow(image[...,::-1])
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##
#
# cv2.putText(image, 'Text to Display', bottom left starting point, Font, Font Size, Color, Thickness)
#
# - FONT_HERSHEY_SIMPLEX, FONT_HERSHEY_PLAIN
# - FONT_HERSHEY_DUPLEX,FONT_HERSHEY_COMPLEX
# - FONT_HERSHEY_TRIPLEX, FONT_HERSHEY_COMPLEX_SMALL
# - FONT_HERSHEY_SCRIPT_SIMPLEX
# - FONT_HERSHEY_SCRIPT_COMPLEX

# %%
image = np.zeros((512,512,3), np.uint8)

cv2.putText(image, 'Hello World!', (50,100), cv2.FONT_HERSHEY_COMPLEX, 2, (0,180,10), 5)
cv2.imshow("Hello World!", image)
plt.imshow(image[...,::-1])
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Persian Text

# %%
image = np.zeros((512,512,3), np.uint8)
text = "سلام دنیا"
cv2.putText(image, text, (75,290), cv2.FONT_HERSHEY_COMPLEX, 2, (100,170,0), 3)
plt.imshow(image[...,::-1])

# %%
#pip install arabic-reshaper
import arabic_reshaper

#pip install python-bidi
from bidi.algorithm import get_display

from PIL import Image, ImageFont, ImageDraw


image = np.zeros((512,512,3), np.uint8)

text_to_be_reshaped = 'سلام دنیا'
reshaped_text = arabic_reshaper.reshape(text_to_be_reshaped) # seperated chars problem
bidi_text = get_display(reshaped_text) #direction problem


text = bidi_text.encode().decode('utf-8') #encoding problem (rectangular boxes!)

pil_image = Image.fromarray(image)
font = ImageFont.truetype("arial", 100, encoding='unic')
draw = ImageDraw.Draw(pil_image)
draw.text((75,290), text, (100,170,0), font=font)

plt.imshow(pil_image)

# %%
np.asarray(pil_image).shape
# Out:
# (512, 512, 3)

# %%
open_cv_image = cv2.cvtColor(np.array(pil_image), cv2.COLOR_RGB2BGR)
cv2.imshow("open_cv_image", open_cv_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# load a custom font

# %%
image = np.zeros((512,512,3), np.uint8)
pil_image = Image.fromarray(image)


font = ImageFont.truetype(font='font/BLotus.ttf', size=100, encoding='unic')
draw = ImageDraw.Draw(pil_image)
draw.text((75,290), text, (255,255,255), font=font)

plt.imshow(pil_image)
