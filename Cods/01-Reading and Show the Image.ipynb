# %% [markdown]
# # read, Store and Showing

# %%
import cv2

# %%
import numpy as np

# %%
img = cv2.imread('./images/girl.jpg')
cv2.imshow("Iranian Girl",img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print (img.shape)
# Out:
# (695, 928, 3)

# %%
print ('Height of Image:', int(img.shape[0]), 'pixels')
print ('Width of Image: ', int(img.shape[1]), 'pixels')
# Out:
# Height of Image: 695 pixels
# Width of Image:  928 pixels

# %%
cv2.imwrite('girl out.png',img)
# Out:
# True

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(img[:,:,::-1])

# %%
#method2
rgb_image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image)

# %%
img1 = cv2.imread('./images/girl.jpg')
img1[200:350,300:350,:]=255
plt.imshow(img1[...,::-1])

# %%
img1[200:350,300:350,:]=(10,100,250)
plt.imshow(img1[...,::-1])
